# %%
import pandas as pd

df= pd.read_csv('/Users/Jiwon/Documents/GitHub/advanced_project/jiwon_project/csv_files/NY_Airbnb_original_df.csv')

# %%
(df['has_availability'] == 't').mean()
# Out:
# np.float64(0.9889725658956429)

# %%
df.loc[df['has_availability'] == 'f']
# Out:
# Empty DataFrame
# Columns: [id, source, name, description, neighborhood_overview, host_id, host_name, host_since, host_location, host_about, host_response_time, host_response_rate, host_acceptance_rate, host_is_superhost, host_neighbourhood, host_listings_count, host_total_listings_count, host_verifications, host_has_profile_pic, host_identity_verified, neighbourhood, neighbourhood_cleansed, neighbourhood_group_cleansed, latitude, longitude, property_type, room_type, accommodates, bathrooms, bathrooms_text, bedrooms, beds, amenities, price, minimum_nights, maximum_nights, minimum_minimum_nights, maximum_minimum_nights, minimum_maximum_nights, maximum_maximum_nights, minimum_nights_avg_ntm, maximum_nights_avg_ntm, calendar_updated, has_availability, availability_30, availability_60, availability_90, availability_365, calendar_last_scraped, number_of_reviews, number_of_reviews_ltm, number_of_reviews_l30d, availability_eoy, number_of_reviews_ly, estimated_occupancy_l365d, estimated_revenue_l365d, first_review, last_review, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, license, instant_bookable, calculated_host_listings_count, calculated_host_listings_count_entire_homes, calculated_host_listings_count_private_rooms, calculated_host_listings_count_shared_rooms, reviews_per_month]
# Index: []
#
# [0 rows x 72 columns]

# %%
df['number_of_reviews'].isnull().sum()
# Out:
# np.int64(0)

# %%
non_review_pct = (df['number_of_reviews'] == 0).sum()/len(df)

print(f'non review pct: {non_review_pct:.2f}')
# Out:
# non review pct: 0.30

# %%
non_review = df[df['number_of_reviews'] == 0]

# %%
pd.set_option('display.max_columns', None)
non_review.loc[non_review['host_since'].isnull()]
# Out:
#                         id       source                            name  \
# 14258   911059653094636598  city scrape                Flatbush 2 Rooms
# 15758  1007480104408240518  city scrape  The perfect Brooklyn 1 bedroom
# 20749  1294847782653168909  city scrape         2 bed 2 bath in BedStuy
#
#                                              description  \
# 14258  This stylish place to stay is perfect for grou...
# 15758  Welcome to your private 1<br />bed 1 bath in t...
# 20749  2 bedroom 2 bathroom in the heart of Bedford S...
#
#       neighborhood_overview    host_id host_name host_since host_location  \
# 14258                   NaN  219152877       NaN        NaT           NaN
# 15758                   NaN   40744019       NaN        NaT           NaN
# 20749                   NaN  130148524       NaN        NaT           NaN
#
#       host_about host_response_time host_response_rate host_acceptance_rate  \
# 14258        NaN                NaN                NaN                  NaN
# 15758        NaN                NaN                NaN                  NaN
# 20749        NaN                NaN                NaN                  NaN
#
#       host_is_superhost host_neighbourhood  host_listings_count  \
# 14258                 f                NaN                  NaN
# 15758                 f                NaN                  NaN
# 20749                 f                NaN                  NaN
#
#        host_total_listings_count host_verifications host_has_profile_pic  \
# 14258                        NaN                NaN                  NaN
# 15758                        NaN                NaN                  NaN
# 20749                        NaN                NaN                  NaN
#
#       host_identity_verified neighbourhood neighbourhood_cleansed  \
# 14258                    NaN           NaN          East Flatbush
# 15758                    NaN           NaN           Williamsburg
# 20749                    NaN           NaN     Bedford-Stuyvesant
#
#       neighbourhood_group_cleansed   latitude  longitude  \
# 14258                     Brooklyn  40.652480 -73.937667
# 15758                     Brooklyn  40.714473 -73.946882
# 20749                     Brooklyn  40.689883 -73.940911
#
#                      property_type        room_type  accommodates  bathrooms  \
# 14258           Entire rental unit  Entire home/apt             3        1.0
# 15758  Private room in rental unit     Private room             2        1.0
# 20749           Entire rental unit  Entire home/apt             4        2.0
#
#       bathrooms_text  bedrooms  beds  \
# 14258         1 bath       2.0   2.0
# 15758  1 shared bath       1.0   1.0
# 20749        2 baths       2.0   2.0
#
#                                                amenities    price  \
# 14258  ["Clothing storage: walk-in closet and wardrob...  $116.00
# 15758                 ["Air conditioning", "Wifi", "TV"]  $160.00
# 20749  ["Blender", "Dedicated workspace", "Extra pill...  $232.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 14258              30             365                    30.0
# 15758              30             365                    30.0
# 20749              30             365                    30.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 14258                    30.0                   365.0                   365.0
# 15758                    30.0                   365.0                   365.0
# 20749                    30.0                   365.0                   365.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 14258                    30.0                   365.0               NaN
# 15758                    30.0                   365.0               NaN
# 20749                    30.0                   365.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 14258                t               28               58               88
# 15758                t               29               59               89
# 20749                t               30               35               46
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 14258               363            2025-03-02                  0
# 15758               269            2025-03-02                  0
# 20749               136            2025-03-02                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d  availability_eoy  \
# 14258                      0                       0               303
# 15758                      0                       0               269
# 20749                      0                       0               136
#
#        number_of_reviews_ly  estimated_occupancy_l365d  \
# 14258                     0                          0
# 15758                     0                          0
# 20749                     0                          0
#
#        estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 14258                      0.0          NaN         NaN                   NaN
# 15758                      0.0          NaN         NaN                   NaN
# 20749                      0.0          NaN         NaN                   NaN
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 14258                     NaN                        NaN
# 15758                     NaN                        NaN
# 20749                     NaN                        NaN
#
#        review_scores_checkin  review_scores_communication  \
# 14258                    NaN                          NaN
# 15758                    NaN                          NaN
# 20749                    NaN                          NaN
#
#        review_scores_location  review_scores_value license instant_bookable  \
# 14258                     NaN                  NaN     NaN                f
# 15758                     NaN                  NaN     NaN                f
# 20749                     NaN                  NaN     NaN                t
#
#        calculated_host_listings_count  \
# 14258                               1
# 15758                               1
# 20749                               1
#
#        calculated_host_listings_count_entire_homes  \
# 14258                                            1
# 15758                                            0
# 20749                                            1
#
#        calculated_host_listings_count_private_rooms  \
# 14258                                             0
# 15758                                             1
# 20749                                             0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 14258                                            0                NaN
# 15758                                            0                NaN
# 20749                                            0                NaN

# %%
non_review = non_review.dropna(subset=['host_since'])
non_review['host_since'] = pd.to_datetime(non_review['host_since'])
non_review['host_since'] = non_review['host_since'].dt.year.astype(int)

non_review['host_since'] >= 2020
# Out:
#                         id       source  \
# 31                   45935  city scrape
# 59                   54466  city scrape
# 107                  63588  city scrape
# 110                 169483  city scrape
# 189                  89427  city scrape
# ...                    ...          ...
# 22303  1366333532374850165  city scrape
# 22304  1366717321390111215  city scrape
# 22305  1366721904709517353  city scrape
# 22306  1366722692755341871  city scrape
# 22307  1366723228243064949  city scrape
#
#                                                    name  \
# 31                         Room in Beautiful Townhouse.
# 59                  Beautiful Uptown Manhattan apartmnt
# 107                                                 LL3
# 110    Very close to Downtown Awesome Private Apartment
# 189                                The Brooklyn Waverly
# ...                                                 ...
# 22303                    Beautiful 1-Bed Apt in Harlem!
# 22304                    Private Room w/ Ensuite Bath H
# 22305                            2 Bedroom on East Side
# 22306                      Stylish 2Bd near Bryant Park
# 22307                      Modern Private Room + Bath H
#
#                                              description  \
# 31     Single bedroom available in 3 bedroom apartmen...
# 59                                                   NaN
# 107    A large bedroom sleeps 3 in a modern 2 bedroom...
# 110    Experience NY just like a local, clean, comfor...
# 189                                                  NaN
# ...                                                  ...
# 22303  Welcome to your temporary home in the vibrant ...
# 22304  Stylish Private Rooms w/ En-Suite Baths in Bro...
# 22305  Located in the Murray Hill area and occupies a...
# 22306  Enjoy everything the city has to offer while l...
# 22307  Stylish Private Rooms w/ En-Suite Baths in Bro...
#
#                                    neighborhood_overview    host_id  \
# 31                                                   NaN     204586
# 59                                                   NaN     253385
# 107    My home sits on a tree lined street across fro...     295128
# 110           Right by the F line<br />No walking needed     807642
# 189                                                  NaN     116599
# ...                                                  ...        ...
# 22303                                                NaN   40019013
# 22304                                                NaN  483056418
# 22305                                                NaN   30283594
# 22306                                                NaN  407304997
# 22307                                                NaN  483056418
#
#                   host_name  host_since  host_location  \
# 31                        L        2010            NaN
# 59                  Douglas        2010   New York, NY
# 107            Carol Gloria        2010   New York, NY
# 110                 Jeffrey        2011   New York, NY
# 189                    Sahr        2010   New York, NY
# ...                     ...         ...            ...
# 22303               Cecilia        2015   New York, NY
# 22304              Kristina        2022   New York, NY
# 22305  Global Luxury Suites        2015  Hawthorne, NJ
# 22306             Boomerang        2021   New York, NY
# 22307              Kristina        2022   New York, NY
#
#                                               host_about host_response_time  \
# 31                                                   NaN                NaN
# 59                                                   NaN                NaN
# 107     I'm a world traveler and a retired customer s...                NaN
# 110    Hi there! I have lived in New York for 19 year...                NaN
# 189    Greetings! I am a working mother and artist wh...                NaN
# ...                                                  ...                ...
# 22303                                                NaN                NaN
# 22304  Are you tired of the tedious and time-consumin...     within an hour
# 22305                                                NaN     within an hour
# 22306  At Boomerang, we believe in the idea "you get ...     within an hour
# 22307  Are you tired of the tedious and time-consumin...     within an hour
#
#       host_response_rate host_acceptance_rate host_is_superhost  \
# 31                   NaN                  NaN                 f
# 59                   NaN                  NaN                 f
# 107                  NaN                  NaN                 f
# 110                  NaN                  NaN                 f
# 189                  NaN                  NaN                 f
# ...                  ...                  ...               ...
# 22303                NaN                  NaN                 f
# 22304               100%                  80%                 t
# 22305                94%                  99%                 f
# 22306                89%                 100%                 f
# 22307               100%                  80%                 t
#
#        host_neighbourhood  host_listings_count  host_total_listings_count  \
# 31                    NaN                  1.0                        2.0
# 59                 Harlem                  1.0                        1.0
# 107             Soundview                  6.0                        7.0
# 110             Gravesend                  2.0                        2.0
# 189          Clinton Hill                  3.0                        5.0
# ...                   ...                  ...                        ...
# 22303                 NaN                  1.0                        2.0
# 22304  Bedford-Stuyvesant                 24.0                       33.0
# 22305         Miami Beach                619.0                     1974.0
# 22306          Park Slope                 26.0                       38.0
# 22307  Bedford-Stuyvesant                 24.0                       33.0
#
#                      host_verifications host_has_profile_pic  \
# 31                   ['email', 'phone']                    t
# 59                   ['email', 'phone']                    t
# 107                  ['email', 'phone']                    t
# 110                  ['email', 'phone']                    t
# 189                  ['email', 'phone']                    t
# ...                                 ...                  ...
# 22303                ['email', 'phone']                    t
# 22304                ['email', 'phone']                    t
# 22305  ['email', 'phone', 'work_email']                    t
# 22306                ['email', 'phone']                    t
# 22307                ['email', 'phone']                    t
#
#       host_identity_verified            neighbourhood neighbourhood_cleansed  \
# 31                         t                      NaN             Mott Haven
# 59                         t                      NaN                 Harlem
# 107                        t  Neighborhood highlights           Clason Point
# 110                        t  Neighborhood highlights              Gravesend
# 189                        t                      NaN           Clinton Hill
# ...                      ...                      ...                    ...
# 22303                      t                      NaN                 Harlem
# 22304                      t                      NaN     Bedford-Stuyvesant
# 22305                      t                      NaN               Kips Bay
# 22306                      t                      NaN       Theater District
# 22307                      t                      NaN     Bedford-Stuyvesant
#
#       neighbourhood_group_cleansed   latitude  longitude  \
# 31                           Bronx  40.806350 -73.922010
# 59                       Manhattan  40.802550 -73.958030
# 107                          Bronx  40.811610 -73.854990
# 110                       Brooklyn  40.606020 -73.970760
# 189                       Brooklyn  40.685130 -73.966480
# ...                            ...        ...        ...
# 22303                    Manhattan  40.813794 -73.952399
# 22304                     Brooklyn  40.685500 -73.919510
# 22305                    Manhattan  40.745290 -73.979380
# 22306                    Manhattan  40.757133 -73.983124
# 22307                     Brooklyn  40.685500 -73.919510
#
#                      property_type        room_type  accommodates  bathrooms  \
# 31     Private room in rental unit     Private room             1        1.0
# 59     Private room in rental unit     Private room             2        1.0
# 107           Private room in home     Private room             3        1.0
# 110             Entire rental unit  Entire home/apt             4        1.0
# 189             Entire rental unit  Entire home/apt            10        1.5
# ...                            ...              ...           ...        ...
# 22303  Private room in rental unit     Private room             1        1.0
# 22304  Private room in rental unit     Private room             2        1.0
# 22305           Entire rental unit  Entire home/apt             5        2.0
# 22306           Entire rental unit  Entire home/apt             4        1.0
# 22307  Private room in rental unit     Private room             2        1.0
#
#        bathrooms_text  bedrooms  beds  \
# 31      1 shared bath       1.0   1.0
# 59             1 bath       1.0   1.0
# 107     1 shared bath       2.0   2.0
# 110            1 bath       1.0   1.0
# 189         1.5 baths       1.0   0.0
# ...               ...       ...   ...
# 22303   1 shared bath       1.0   1.0
# 22304  1 private bath       1.0   0.0
# 22305         2 baths       2.0   3.0
# 22306          1 bath       2.0   2.0
# 22307  1 private bath       1.0   0.0
#
#                                                amenities    price  \
# 31     ["Fire extinguisher", "First aid kit", "Breakf...   $60.00
# 59     ["TV with standard cable", "Oven", "Gym", "Dis...  $172.00
# 107    ["Oven", "Fire extinguisher", "First aid kit",...  $107.00
# 110    ["TV with standard cable", "Kitchen", "First a...  $231.00
# 189    ["TV with standard cable", "Outdoor furniture"...  $800.00
# ...                                                  ...      ...
# 22303  ["Air conditioning", "Carbon monoxide alarm", ...   $72.00
# 22304  ["Air conditioning", "Carbon monoxide alarm", ...   $58.00
# 22305  ["Air conditioning", "Carbon monoxide alarm", ...  $299.00
# 22306  ["Oven", "Gym", "Blender", "Dedicated workspac...  $200.00
# 22307  ["Air conditioning", "Carbon monoxide alarm", ...   $58.00
#
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 31                 30              40                    30.0
# 59                 30              60                    30.0
# 107                30            1125                    30.0
# 110                30              30                    30.0
# 189                30             365                    30.0
# ...               ...             ...                     ...
# 22303              30             365                    30.0
# 22304              30             365                    30.0
# 22305              30             365                    30.0
# 22306              30             365                    30.0
# 22307              30             365                    30.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 31                       30.0                    40.0                    40.0
# 59                       30.0                    60.0                    60.0
# 107                      30.0                  1125.0                  1125.0
# 110                      30.0                  1125.0                  1125.0
# 189                      30.0                   365.0                   365.0
# ...                       ...                     ...                     ...
# 22303                    30.0                   365.0                   365.0
# 22304                    30.0                   365.0                   365.0
# 22305                    30.0                   365.0                   365.0
# 22306                    30.0                   365.0                   365.0
# 22307                    30.0                   365.0                   365.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 31                       30.0                    40.0               NaN
# 59                       30.0                    60.0               NaN
# 107                      30.0                  1125.0               NaN
# 110                      30.0                  1125.0               NaN
# 189                      30.0                   365.0               NaN
# ...                       ...                     ...               ...
# 22303                    30.0                   365.0               NaN
# 22304                    30.0                   365.0               NaN
# 22305                    30.0                   365.0               NaN
# 22306                    30.0                   365.0               NaN
# 22307                    30.0                   365.0               NaN
#
#       has_availability  availability_30  availability_60  availability_90  \
# 31                   t               24               54               83
# 59                   t               30               60               90
# 107                  t                0                0                0
# 110                  t                0                0                0
# 189                  t               23               53               83
# ...                ...              ...              ...              ...
# 22303                t               23               53               83
# 22304                t               28               58               88
# 22305                t               30               39               39
# 22306                t               30               60               90
# 22307                t               28               58               88
#
#        availability_365 calendar_last_scraped  number_of_reviews  \
# 31                   83            2025-03-02                  0
# 59                  365            2025-03-02                  0
# 107                   0            2025-03-03                  0
# 110                 182            2025-03-02                  0
# 189                 358            2025-03-02                  0
# ...                 ...                   ...                ...
# 22303               358            2025-03-02                  0
# 22304               363            2025-03-02                  0
# 22305                99            2025-03-02                  0
# 22306               365            2025-03-02                  0
# 22307               363            2025-03-02                  0
#
#        number_of_reviews_ltm  number_of_reviews_l30d  availability_eoy  \
# 31                         0                       0                83
# 59                         0                       0               305
# 107                        0                       0                 0
# 110                        0                       0               122
# 189                        0                       0               298
# ...                      ...                     ...               ...
# 22303                      0                       0               298
# 22304                      0                       0               303
# 22305                      0                       0                39
# 22306                      0                       0               305
# 22307                      0                       0               303
#
#        number_of_reviews_ly  estimated_occupancy_l365d  \
# 31                        0                          0
# 59                        0                          0
# 107                       0                          0
# 110                       0                          0
# 189                       0                          0
# ...                     ...                        ...
# 22303                     0                          0
# 22304                     0                          0
# 22305                     0                          0
# 22306                     0                          0
# 22307                     0                          0
#
#        estimated_revenue_l365d first_review last_review  review_scores_rating  \
# 31                         0.0          NaN         NaN                   NaN
# 59                         0.0          NaN         NaN                   NaN
# 107                        0.0          NaN         NaN                   NaN
# 110                        0.0          NaN         NaN                   NaN
# 189                        0.0          NaN         NaN                   NaN
# ...                        ...          ...         ...                   ...
# 22303                      0.0          NaN         NaN                   NaN
# 22304                      0.0          NaN         NaN                   NaN
# 22305                      0.0          NaN         NaN                   NaN
# 22306                      0.0          NaN         NaN                   NaN
# 22307                      0.0          NaN         NaN                   NaN
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 31                        NaN                        NaN
# 59                        NaN                        NaN
# 107                       NaN                        NaN
# 110                       NaN                        NaN
# 189                       NaN                        NaN
# ...                       ...                        ...
# 22303                     NaN                        NaN
# 22304                     NaN                        NaN
# 22305                     NaN                        NaN
# 22306                     NaN                        NaN
# 22307                     NaN                        NaN
#
#        review_scores_checkin  review_scores_communication  \
# 31                       NaN                          NaN
# 59                       NaN                          NaN
# 107                      NaN                          NaN
# 110                      NaN                          NaN
# 189                      NaN                          NaN
# ...                      ...                          ...
# 22303                    NaN                          NaN
# 22304                    NaN                          NaN
# 22305                    NaN                          NaN
# 22306                    NaN                          NaN
# 22307                    NaN                          NaN
#
#        review_scores_location  review_scores_value license instant_bookable  \
# 31                        NaN                  NaN     NaN                t
# 59                        NaN                  NaN     NaN                f
# 107                       NaN                  NaN     NaN                f
# 110                       NaN                  NaN     NaN                t
# 189                       NaN                  NaN     NaN                f
# ...                       ...                  ...     ...              ...
# 22303                     NaN                  NaN     NaN                f
# 22304                     NaN                  NaN     NaN                f
# 22305                     NaN                  NaN     NaN                f
# 22306                     NaN                  NaN     NaN                t
# 22307                     NaN                  NaN     NaN                f
#
#        calculated_host_listings_count  \
# 31                                  1
# 59                                  1
# 107                                 6
# 110                                 2
# 189                                 3
# ...                               ...
# 22303                               1
# 22304                              24
# 22305                              48
# 22306                              25
# 22307                              24
#
#        calculated_host_listings_count_entire_homes  \
# 31                                               0
# 59                                               0
# 107                                              0
# 110                                              1
# 189                                              1
# ...                                            ...
# 22303                                            0
# 22304                                            0
# 22305                                           48
# 22306                                           25
# 22307                                            0
#
#        calculated_host_listings_count_private_rooms  \
# 31                                                1
# 59                                                1
# 107                                               6
# 110                                               1
# 189                                               2
# ...                                             ...
# 22303                                             1
# 22304                                            24
# 22305                                             0
# 22306                                             0
# 22307                                            24
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 31                                               0                NaN
# 59                                               0                NaN
# 107                                              0                NaN
# 110                                              0                NaN
# 189                                              0                NaN
# ...                                            ...                ...
# 22303                                            0                NaN
# 22304                                            0                NaN
# 22305                                            0                NaN
# 22306                                            0                NaN
# 22307                                            0                NaN
#
# [6795 rows x 72 columns]

# %%
df['availability_365'].describe()
# Out:
# count    22308.000000
# mean       239.724718
# std        112.168551
# min          0.000000
# 25%        151.000000
# 50%        269.000000
# 75%        352.000000
# max        365.000000
# Name: availability_365, dtype: float64
